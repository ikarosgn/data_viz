# %% [markdown]
# <a href="https://colab.research.google.com/github/ikarosgn/data_viz/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
oct57 = pd.read_excel('/content/drive/MyDrive/dataviz_2021/-.57-.58-1.xls',sheet_name=0)
oct57
# Out:
#                                           Unnamed: 0  ...                แบบ สขร. 1
# 0    สรุปผลการดำเนินการจัดจ้างในรอบเดือน ตุลาคม 2557  ...                       NaN
# 1         สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 2                                                NaN  ...                       NaN
# 3                                              ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 4                                                ที่  ...                       NaN
# ..                                               ...  ...                       ...
# 99                                                56  ...            เป็นผู้รับจ้าง
# 100                                               57  ...            เป็นผู้รับจ้าง
# 101                                               58  ...            เป็นผู้รับจ้าง
# 102                                               59  ...            เป็นผู้รับจ้าง
# ...

# %%
oct58 = pd.read_excel('/content/drive/MyDrive/dataviz_2021/58-..59-3.xlsx',sheet_name=0)
oct58
# Out:
#               สรุปผลดำเนินการจัดซื้อจัดจ้างในรอบเดือน  ...                      Unnamed: 12
# 0   สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี (สป...  ...                              NaN
# 1                              ประจำเดือน ตุลาคม 2558  ...                              NaN
# 2                                                 NaN  ...                              NaN
# 3                                            ลำดับที่  ...  วันที่สัญญาหรือข้อตกลงซื้อ/จ้าง
# 4                                                   1  ...                        5 ต.ค. 58
# ..                                                ...  ...                              ...
# 70                                                NaN  ...                              NaN
# 71                                                 14  ...                       27 ต.ค. 58
# 72                                                NaN  ...                              NaN
# ...

# %%
oct57_1 = pd.read_excel('/content/drive/MyDrive/dataviz_2021/-.57-.58-1 (1).xls',sheet_name=0)
oct57_1
# Out:
#                                          Unnamed: 0  ...                แบบ สขร. 1
# 0   สรุปผลการดำเนินการจัดซื้อในรอบเดือน ตุลาคม 2557  ...                       NaN
# 1        สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 2                                               NaN  ...                       NaN
# 3                                             ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 4                                               ที่  ...                       NaN
# 5                                                 1  ...   เป็นผู้ให้บริการจำหน่าย
# 6                                                 2  ...   เป็นผู้ให้บริการจำหน่าย
# 7                                                 3  ...   เป็นผู้ให้บริการจำหน่าย
# 8                                                 4  ...   เป็นผู้ให้บริการจำหน่าย
# 9                                                 5  ...   เป็นผู้ให้บริการจำหน่าย
# ...
