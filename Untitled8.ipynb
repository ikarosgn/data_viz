# %% [markdown]
# <a href="https://colab.research.google.com/github/ikarosgn/data_viz/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/dataviz_2021'

# %%
data_path = os.path.join(path,'-.57-.58-1.xls')

# %%
data1_df = pd.read_excel(data_path,header=4,skipfooter=20)
data1_df
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...           เป็นผู้รับจ้าง
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# ..   ...  ...                      ...
# 75    42  ...           เป็นผู้รับจ้าง
# 76    43  ...           เป็นผู้รับจ้าง
# 77    44  ...           เป็นผู้รับจ้าง
# 78    45  ...           เป็นผู้รับจ้าง
# 79   NaN  ...               แบบ สขร. 1
#
# [80 rows x 9 columns]

# %%
data1_df = data1_df.drop([0])
data1_df
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...           เป็นผู้รับจ้าง
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# 5      5  ...           เป็นผู้รับจ้าง
# ..   ...  ...                      ...
# 75    42  ...           เป็นผู้รับจ้าง
# 76    43  ...           เป็นผู้รับจ้าง
# 77    44  ...           เป็นผู้รับจ้าง
# 78    45  ...           เป็นผู้รับจ้าง
# 79   NaN  ...               แบบ สขร. 1
#
# [79 rows x 9 columns]

# %%
data2_df = pd.read_excel(data_path,sheet_name='พย.57',header=4,skipfooter=30)
data2_df
# Out:
#   ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0   ที่  ...                      NaN
# 1     1  ...           เป็นผู้รับจ้าง
# 2     2  ...           เป็นผู้รับจ้าง
# 3     3  ...           เป็นผู้รับจ้าง
# 4     4  ...           เป็นผู้รับจ้าง
# 5     5  ...           เป็นผู้รับจ้าง
# 6     6  ...           เป็นผู้รับจ้าง
#
# [7 rows x 9 columns]

# %%
data2_df = data2_df.drop([0])
data2_df = data2_df.drop([16])
data2_df = data2_df.drop([17])
data2_df = data2_df.drop([18])
data2_df = data2_df.drop([19])
data2_df = data2_df.drop([20])
data2_df = data2_df.drop([21])
data2_df = data2_df.drop([37])
data2_df = data2_df.drop([38])
data2_df = data2_df.drop([39])
data2_df = data2_df.drop([40])
data2_df = data2_df.drop([41])
data2_df = data2_df.drop([42])
data2_df = data2_df.drop([43])
data2_df = data2_df.drop([44])
data2_df = data2_df.drop([45])
data2_df = data2_df.drop([46])
data2_df = data2_df.drop([47])
data2_df = data2_df.drop([48])
data2_df = data2_df.drop([49])
data2_df = data2_df.drop([50])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-5ba54af0bd85> in <module>()
#       1 data2_df = data2_df.drop([0])
#       2
# ----> 3 data2_df = data2_df.drop([17])
#       4 data2_df = data2_df.drop([18])
#       5 data2_df = data2_df.drop([19])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
# ...

# %%
data_all = pd.concat([data1_df,data2_df])
data_all
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...           เป็นผู้รับจ้าง
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# 5      5  ...           เป็นผู้รับจ้าง
# ..   ...  ...                      ...
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# 5      5  ...           เป็นผู้รับจ้าง
# 6      6  ...           เป็นผู้รับจ้าง
#
# [85 rows x 9 columns]

# %%
data = data_all.rename(columns={'Unnamed: 5':'ราคาเสรอ','Unnamed: 7':'ราคาาซื้อ'})
data
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...           เป็นผู้รับจ้าง
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# 5      5  ...           เป็นผู้รับจ้าง
# ..   ...  ...                      ...
# 2      2  ...           เป็นผู้รับจ้าง
# 3      3  ...           เป็นผู้รับจ้าง
# 4      4  ...           เป็นผู้รับจ้าง
# 5      5  ...           เป็นผู้รับจ้าง
# 6      6  ...           เป็นผู้รับจ้าง
#
# [85 rows x 9 columns]
