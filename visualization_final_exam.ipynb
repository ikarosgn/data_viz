# %% [markdown]
# <a href="https://colab.research.google.com/github/ikarosgn/data_viz/blob/main/visualization_final_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from datetime import datetime as dt
from datetime import time
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/content/drive/My Drive/dataviz_2021'

# %%
data_tran = pd.read_excel(os.path.join(path,'passenger-covid19.xlsx'),sheet_name='2563-2564 รวมในประเทศ',skiprows=1)
data_tran
# Out:
#                                            Unnamed: 0  ...  2021-04-26 00:00:00
# 0                                         ทางถนน (คน)  ...               580580
# 1                                         ทางราง (คน)  ...               418835
# 2                                         ทางน้ำ (คน)  ...                53591
# 3                                      ทางอากาศ* (คน)  ...                13585
# 4                              รวมประชาชนเดินทาง (คน)  ...              1066591
# 5                                                 NaN  ...                  NaN
# 6                   รถส่วนบุคคล เข้า - ออก กทม. (คัน)  ...              1836042
# 7          ---- รายละเอียดแยกรายรูปแบบการเดินทาง ----  ...                  NaN
# 8                                              ทางถนน  ...  2021-04-26 00:00:00
# 9   รถโดยสารประจำทางใน กทม. และปริมณฑล (ขสมก. และ ...  ...               541053
# 10  รถโดยสารประจำทางระหว่าง กทม. - ตจว. \n(บขส. แล...  ...                27701
# ...

# %%
data1 = data_tran[0:7] #จัดการข้อมูลเพื่อจะทำ ข้อที่ 1 
data1.head()
# Out:
#                Unnamed: 0  ... 2021-04-26 00:00:00
# 0             ทางถนน (คน)  ...              580580
# 1             ทางราง (คน)  ...              418835
# 2             ทางน้ำ (คน)  ...               53591
# 3          ทางอากาศ* (คน)  ...               13585
# 4  รวมประชาชนเดินทาง (คน)  ...             1066591
#
# [5 rows x 483 columns]

# %%
tranreal = data1.drop(index=5) #จัดการข้อมูลที่ไม่ใช้
tranreal
# Out:
#                           Unnamed: 0  ... 2021-04-26 00:00:00
# 0                        ทางถนน (คน)  ...              580580
# 1                        ทางราง (คน)  ...              418835
# 2                        ทางน้ำ (คน)  ...               53591
# 3                     ทางอากาศ* (คน)  ...               13585
# 4             รวมประชาชนเดินทาง (คน)  ...             1066591
# 6  รถส่วนบุคคล เข้า - ออก กทม. (คัน)  ...             1836042
#
# [6 rows x 483 columns]

# %% [markdown]
# #ข้อ 1 เปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในแต่ละเดือน

# %%
kho1_1 = tranreal.iloc[4] #นำข้อมูลที่ใช้มาสร้างตัวแปรใหม่
kho1_1
# Out:
# Unnamed: 0             รวมประชาชนเดินทาง (คน)
# 2020-01-01 00:00:00                   2743864
# 2020-01-02 00:00:00                   3370836
# 2020-01-03 00:00:00                   3520819
# 2020-01-04 00:00:00                   2975450
#                                 ...
# 2021-04-22 00:00:00                   1175707
# 2021-04-23 00:00:00                   1180619
# 2021-04-24 00:00:00                    869281
# 2021-04-25 00:00:00                    708446
# 2021-04-26 00:00:00                   1066591
# Name: 4, Length: 483, dtype: object

# %%
kho1_2 = pd.DataFrame(kho1_1).reset_index() #สร้างตารางใหม่ให้ข้อมูลที่จะใช้ในข้อ 1 
kho1_2
# Out:
#                    index                       4
# 0             Unnamed: 0  รวมประชาชนเดินทาง (คน)
# 1    2020-01-01 00:00:00                 2743864
# 2    2020-01-02 00:00:00                 3370836
# 3    2020-01-03 00:00:00                 3520819
# 4    2020-01-04 00:00:00                 2975450
# ..                   ...                     ...
# 478  2021-04-22 00:00:00                 1175707
# 479  2021-04-23 00:00:00                 1180619
# 480  2021-04-24 00:00:00                  869281
# 481  2021-04-25 00:00:00                  708446
# 482  2021-04-26 00:00:00                 1066591
#
# [483 rows x 2 columns]

# %%
kho1_2.drop(index=0,inplace=True) #ลบแถวที่ 0 ออกเนื่องจากใช้ไม่ได้
kho1_2
# Out:
#                    index        4
# 1    2020-01-01 00:00:00  2743864
# 2    2020-01-02 00:00:00  3370836
# 3    2020-01-03 00:00:00  3520819
# 4    2020-01-04 00:00:00  2975450
# 5    2020-01-05 00:00:00  2835519
# ..                   ...      ...
# 478  2021-04-22 00:00:00  1175707
# 479  2021-04-23 00:00:00  1180619
# 480  2021-04-24 00:00:00   869281
# 481  2021-04-25 00:00:00   708446
# 482  2021-04-26 00:00:00  1066591
#
# [482 rows x 2 columns]

# %%
kho1_2.rename(columns={'index':'date',4:'Sumtravel'},inplace=True) #ตั้งชื่อคอลัมใหม่
kho1_2
# Out:
#                     date Sumtravel
# 1    2020-01-01 00:00:00   2743864
# 2    2020-01-02 00:00:00   3370836
# 3    2020-01-03 00:00:00   3520819
# 4    2020-01-04 00:00:00   2975450
# 5    2020-01-05 00:00:00   2835519
# ..                   ...       ...
# 478  2021-04-22 00:00:00   1175707
# 479  2021-04-23 00:00:00   1180619
# 480  2021-04-24 00:00:00    869281
# 481  2021-04-25 00:00:00    708446
# 482  2021-04-26 00:00:00   1066591
#
# [482 rows x 2 columns]

# %%
kho1_2['date'] = pd.to_datetime(kho1_2['date'],format='%d/%m/%Y') #ทำข้อมูลให้เป็น date time 
kho1_2
# Out:
#           date Sumtravel
# 1   2020-01-01   2743864
# 2   2020-01-02   3370836
# 3   2020-01-03   3520819
# 4   2020-01-04   2975450
# 5   2020-01-05   2835519
# ..         ...       ...
# 478 2021-04-22   1175707
# 479 2021-04-23   1180619
# 480 2021-04-24    869281
# 481 2021-04-25    708446
# 482 2021-04-26   1066591
#
# [482 rows x 2 columns]

# %%
kho1_2['month']= kho1_2['date'].dt.month #จัดความถี่เป็นเดือน
kho1_2
# Out:
#           date Sumtravel  month
# 1   2020-01-01   2743864      1
# 2   2020-01-02   3370836      1
# 3   2020-01-03   3520819      1
# 4   2020-01-04   2975450      1
# 5   2020-01-05   2835519      1
# ..         ...       ...    ...
# 478 2021-04-22   1175707      4
# 479 2021-04-23   1180619      4
# 480 2021-04-24    869281      4
# 481 2021-04-25    708446      4
# 482 2021-04-26   1066591      4
#
# [482 rows x 3 columns]

# %%
kho1_3 = kho1_2.groupby('month')['Sumtravel'].sum() #นำความถี่รวมเป็นเดือน
kho1_3
# Out:
# month
# 1     145794569
# 2     139515123
# 3     123150402
# 4      58145633
# 5      32569755
# 6      48464966
# 7      62241436
# 8      67208460
# 9      67916587
# 10     68487852
# 11     68527999
# 12     65242215
# Name: Sumtravel, dtype: int64

# %%
kho1_4 = pd.DataFrame(kho1_3).reset_index() #สร้างตารางใหม่
kho1_4
# Out:
#     month  Sumtravel
# 0       1  145794569
# 1       2  139515123
# 2       3  123150402
# 3       4   58145633
# 4       5   32569755
# 5       6   48464966
# 6       7   62241436
# 7       8   67208460
# 8       9   67916587
# 9      10   68487852
# 10     11   68527999
# 11     12   65242215

# %%
data_covid19 = pd.read_csv(os.path.join(path,'covid19cases.csv')) #เรียกข้อมูลผู้ป่วย
data_covid19.head()
# Out:
#    No. announce_date  ... province_of_onset district_of_onset
# 0    1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1    2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2    3     22/1/2020  ...            นครปฐม             เมือง
# 3    4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4    5     24/1/2020  ...     กรุงเทพมหานคร               NaN
#
# [5 rows x 11 columns]

# %%
covid1 = data_covid19.iloc[:,:2] #เอาข้อมูลที่ได้ใช้

# %%
covid1['announce_date'] = pd.to_datetime(covid1['announce_date'],format='%d/%m/%Y') #ทำข้อมูลให้เป็น date time
covid1
# Out:
#          No. announce_date
# 0          1    2020-01-12
# 1          2    2020-01-17
# 2          3    2020-01-22
# 3          4    2020-01-22
# 4          5    2020-01-24
# ...      ...           ...
# 57505  57506    2021-04-26
# 57506  57507    2021-04-26
# 57507  57508    2021-04-26
# 57508  57509    2021-04-26
# 57509  57510    2021-04-26
#
# [57510 rows x 2 columns]

# %%
Count = covid1.groupby('announce_date')['No.'].count() #หาความถี่ของผู้ป่วยตามเดือน
Count
# Out:
# announce_date
# 2020-01-12       1
# 2020-01-17       1
# 2020-01-22       2
# 2020-01-24       1
# 2020-01-25       1
#               ...
# 2021-04-22    1470
# 2021-04-23    2070
# 2021-04-24    2839
# 2021-04-25    2438
# 2021-04-26    2048
# Name: No., Length: 415, dtype: int64

# %%
recount = pd.DataFrame(Count).reset_index() #สร้างตารางความถี่ของผู้ป่วยตามเดือน
recount
# Out:
#     announce_date   No.
# 0      2020-01-12     1
# 1      2020-01-17     1
# 2      2020-01-22     2
# 3      2020-01-24     1
# 4      2020-01-25     1
# ..            ...   ...
# 410    2021-04-22  1470
# 411    2021-04-23  2070
# 412    2021-04-24  2839
# 413    2021-04-25  2438
# 414    2021-04-26  2048
#
# [415 rows x 2 columns]

# %%
recount.rename(columns={'index':'announce_date','No.':'count'},inplace=True) #ตั้งชื่อหัวตารางใหม่
recount
# Out:
#     announce_date  count
# 0      2020-01-12      1
# 1      2020-01-17      1
# 2      2020-01-22      2
# 3      2020-01-24      1
# 4      2020-01-25      1
# ..            ...    ...
# 410    2021-04-22   1470
# 411    2021-04-23   2070
# 412    2021-04-24   2839
# 413    2021-04-25   2438
# 414    2021-04-26   2048
#
# [415 rows x 2 columns]

# %%
recount['month']= recount['announce_date'].dt.month #สร้างความถี่ตามวัน
recount
# Out:
#     announce_date  count  month
# 0      2020-01-12      1      1
# 1      2020-01-17      1      1
# 2      2020-01-22      2      1
# 3      2020-01-24      1      1
# 4      2020-01-25      1      1
# ..            ...    ...    ...
# 410    2021-04-22   1470      4
# 411    2021-04-23   2070      4
# 412    2021-04-24   2839      4
# 413    2021-04-25   2438      4
# 414    2021-04-26   2048      4
#
# [415 rows x 3 columns]

# %%
recount1 = recount.groupby('month')['count'].sum() #รวมความถี่ตามเดือน
recount1
# Out:
# month
# 1     11917
# 2      7192
# 3      4521
# 4     29950
# 5       127
# 6        90
# 7       139
# 8       102
# 9       152
# 10      216
# 11      218
# 12     2886
# Name: count, dtype: int64

# %%
re1 = pd.DataFrame(recount1).reset_index() #ได้จำนวนผู้ป่วยในแต่ละเดือน
re1
# Out:
#     month  count
# 0       1  11917
# 1       2   7192
# 2       3   4521
# 3       4  29950
# 4       5    127
# 5       6     90
# 6       7    139
# 7       8    102
# 8       9    152
# 9      10    216
# 10     11    218
# 11     12   2886

# %%
re1['Sumtravel']=kho1_4['Sumtravel'] #ตารางจำนวนผู้ป่วยในแต่ละเดือนและจำนวนการเดินทางทั้งหมดในแต่ละเดือน
re1
# Out:
#     month  count  Sumtravel
# 0       1  11917  145794569
# 1       2   7192  139515123
# 2       3   4521  123150402
# 3       4  29950   58145633
# 4       5    127   32569755
# 5       6     90   48464966
# 6       7    139   62241436
# 7       8    102   67208460
# 8       9    152   67916587
# 9      10    216   68487852
# 10     11    218   68527999
# 11     12   2886   65242215

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
plt.figure(figsize=(15, 10))
plt.plot(re1['month'],re1['count'],color = 'pink',label = 'จำนวนผู้ป่วยที่ติดเชื้อ')
plt.plot(re1['month'],re1['Sumtravel'],color ='blue',label = 'จำนวนคนเดินทางทั้งหมด')
plt.xlabel("month")
plt.ylabel("จำนวน")
plt.title('กราฟเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในแต่ละเดือน')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3585 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ##สรุปข้อ 1
# #เหตุผลกราฟเส้นเพราะว่ากราฟเส้นดูง่ายเมื่อเปรียบเทียบจำนวน
# #จากกราฟแท่งแบบแบ่งชั้นและกราฟเส้นพบว่า จำนวนผู้เดือนทางทางบกมีจำนวนคนเดินทางมากกว่าจำนวนผู้ป่วย จำนวนการเดินทางในเดือนที่ 1 มากที่สุด และ จำนวนการเดินทางในเดือนที่ 5 น้อยที่สุด

# %% [markdown]
# #ข้อ2เปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนนั้นๆ

# %%
ts = tranreal.transpose() #กลับข้่อมูลเพื่อความง่ายต่อการจัดการข้อมูล
z
# Out:
#                                0  ...                                  6
# Unnamed: 0           ทางถนน (คน)  ...  รถส่วนบุคคล เข้า - ออก กทม. (คัน)
# 2020-01-01 00:00:00      1483255  ...                            2310406
# 2020-01-02 00:00:00      1705026  ...                            2538456
# 2020-01-03 00:00:00      1752572  ...                            2649091
# 2020-01-04 00:00:00      1576146  ...                            2515920
# ...                          ...  ...                                ...
# 2021-04-22 00:00:00       631892  ...                            1940760
# 2021-04-23 00:00:00       635830  ...                            1948547
# 2021-04-24 00:00:00       516751  ...                            1760192
# 2021-04-25 00:00:00       425707  ...                            1478813
# 2021-04-26 00:00:00       580580  ...                            1836042
#
# [483 rows x 6 columns]

# %%
ts1 = ts.iloc[:,:4] #เลือกเฉพาะ คอลัมที่ใช้งาน
ts1
# Out:
#                                0            1            2               3
# Unnamed: 0           ทางถนน (คน)  ทางราง (คน)  ทางน้ำ (คน)  ทางอากาศ* (คน)
# 2020-01-01 00:00:00      1483255       885353       272578          102678
# 2020-01-02 00:00:00      1705026      1269207       291990          104613
# 2020-01-03 00:00:00      1752572      1366412       301260          100575
# 2020-01-04 00:00:00      1576146      1027281       271171          100852
# ...                          ...          ...          ...             ...
# 2021-04-22 00:00:00       631892       467490        60186           16139
# 2021-04-23 00:00:00       635830       474554        54870           15365
# 2021-04-24 00:00:00       516751       289943        48885           13702
# 2021-04-25 00:00:00       425707       223384        42733           16622
# 2021-04-26 00:00:00       580580       418835        53591           13585
#
# [483 rows x 4 columns]

# %%
ts2 = pd.DataFrame(ts1).reset_index()  #จัดการแถวที่ 0 
ts2
# Out:
#                    index            0            1            2               3
# 0             Unnamed: 0  ทางถนน (คน)  ทางราง (คน)  ทางน้ำ (คน)  ทางอากาศ* (คน)
# 1    2020-01-01 00:00:00      1483255       885353       272578          102678
# 2    2020-01-02 00:00:00      1705026      1269207       291990          104613
# 3    2020-01-03 00:00:00      1752572      1366412       301260          100575
# 4    2020-01-04 00:00:00      1576146      1027281       271171          100852
# ..                   ...          ...          ...          ...             ...
# 478  2021-04-22 00:00:00       631892       467490        60186           16139
# 479  2021-04-23 00:00:00       635830       474554        54870           15365
# 480  2021-04-24 00:00:00       516751       289943        48885           13702
# 481  2021-04-25 00:00:00       425707       223384        42733           16622
# 482  2021-04-26 00:00:00       580580       418835        53591           13585
#
# ...

# %%
ts3 = ts2.iloc[1:,:] 
ts3
# Out:
#                    index        0        1       2       3
# 1    2020-01-01 00:00:00  1483255   885353  272578  102678
# 2    2020-01-02 00:00:00  1705026  1269207  291990  104613
# 3    2020-01-03 00:00:00  1752572  1366412  301260  100575
# 4    2020-01-04 00:00:00  1576146  1027281  271171  100852
# 5    2020-01-05 00:00:00  1565134   915425  254176  100784
# ..                   ...      ...      ...     ...     ...
# 478  2021-04-22 00:00:00   631892   467490   60186   16139
# 479  2021-04-23 00:00:00   635830   474554   54870   15365
# 480  2021-04-24 00:00:00   516751   289943   48885   13702
# 481  2021-04-25 00:00:00   425707   223384   42733   16622
# 482  2021-04-26 00:00:00   580580   418835   53591   13585
#
# [482 rows x 5 columns]

# %%
ts3.rename(columns={'index':'announce_date',0:'ทางถนน',1:'ทางราง',2:'ทางน้ำ',3:'ทางอากาศ'},inplace=True)  #ตั้งชื่อแถวตามการใช้งาน
ts3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#            announce_date   ทางถนน   ทางราง  ทางน้ำ ทางอากาศ
# 1    2020-01-01 00:00:00  1483255   885353  272578   102678
# 2    2020-01-02 00:00:00  1705026  1269207  291990   104613
# 3    2020-01-03 00:00:00  1752572  1366412  301260   100575
# 4    2020-01-04 00:00:00  1576146  1027281  271171   100852
# 5    2020-01-05 00:00:00  1565134   915425  254176   100784
# ..                   ...      ...      ...     ...      ...
# 478  2021-04-22 00:00:00   631892   467490   60186    16139
# 479  2021-04-23 00:00:00   635830   474554   54870    15365
# 480  2021-04-24 00:00:00   516751   289943   48885    13702
# ...

# %%
ts3 = ts3.iloc[:]
# Out:
# 482    580580
# Name: ทางถนน, dtype: object

# %%
ts3['announce_date'] = pd.to_datetime(ts3['announce_date'],format='%d/%m/%Y')  #ทำ date time 
ts3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     announce_date   ทางถนน   ทางราง  ทางน้ำ ทางอากาศ
# 1      2020-01-01  1483255   885353  272578   102678
# 2      2020-01-02  1705026  1269207  291990   104613
# 3      2020-01-03  1752572  1366412  301260   100575
# 4      2020-01-04  1576146  1027281  271171   100852
# 5      2020-01-05  1565134   915425  254176   100784
# ..            ...      ...      ...     ...      ...
# 478    2021-04-22   631892   467490   60186    16139
# 479    2021-04-23   635830   474554   54870    15365
# 480    2021-04-24   516751   289943   48885    13702
# ...

# %%
ts3['month']= ts3['announce_date'].dt.month  #หา cout เพื่อที่จะไปสร้างกราฟ
ts3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     announce_date   ทางถนน   ทางราง  ทางน้ำ ทางอากาศ  month
# 1      2020-01-01  1483255   885353  272578   102678      1
# 2      2020-01-02  1705026  1269207  291990   104613      1
# 3      2020-01-03  1752572  1366412  301260   100575      1
# 4      2020-01-04  1576146  1027281  271171   100852      1
# 5      2020-01-05  1565134   915425  254176   100784      1
# ..            ...      ...      ...     ...      ...    ...
# 478    2021-04-22   631892   467490   60186    16139      4
# 479    2021-04-23   635830   474554   54870    15365      4
# ...

# %%
ts4 = ts3.groupby('month')['ทางถนน','ทางราง','ทางน้ำ','ทางอากาศ'].sum() #รวมจำนวนการเดินทางทั้งหมด
ts4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#          ทางถนน    ทางราง    ทางน้ำ  ทางอากาศ
# month
# 1      73801944  57709498  10520103   3763024
# 2      70580014  56246335   9151087   3537687
# 3      62262479  52319268   5198977   3369678
# 4      31873641  21092430   3826728   1352834
# 5      19371815  11482880   1503935    211125
# 6      25723627  19881012   2241446    618881
# 7      31550369  25890919   3481589   1318559
# 8      33311862  29055512   3176923   1664163
# 9      32661894  30044159   3344351   1866183
# 10     33084230  30259559   3012379   2131684
# 11     32234047  30409897   3402311   2481744
# 12     31315704  27947720   3690246   2288545

# %%
ts5 = pd.DataFrame(ts4).reset_index()  #สร้างเดือนขึ้นมาเพื่อจะไปสร้างกราฟ
ts5
# Out:
#     month    ทางถนน    ทางราง    ทางน้ำ  ทางอากาศ
# 0       1  73801944  57709498  10520103   3763024
# 1       2  70580014  56246335   9151087   3537687
# 2       3  62262479  52319268   5198977   3369678
# 3       4  31873641  21092430   3826728   1352834
# 4       5  19371815  11482880   1503935    211125
# 5       6  25723627  19881012   2241446    618881
# 6       7  31550369  25890919   3481589   1318559
# 7       8  33311862  29055512   3176923   1664163
# 8       9  32661894  30044159   3344351   1866183
# 9      10  33084230  30259559   3012379   2131684
# 10     11  32234047  30409897   3402311   2481744
# 11     12  31315704  27947720   3690246   2288545

# %%
ts5['จำนวนผู้ป่วย'] = re1['count']  #เพิ่มจำนวนผู้ป่วย
ts5
# Out:
#     month    ทางถนน    ทางราง    ทางน้ำ  ทางอากาศ  จำนวนผู้ป่วย
# 0       1  73801944  57709498  10520103   3763024         11917
# 1       2  70580014  56246335   9151087   3537687          7192
# 2       3  62262479  52319268   5198977   3369678          4521
# 3       4  31873641  21092430   3826728   1352834         29950
# 4       5  19371815  11482880   1503935    211125           127
# 5       6  25723627  19881012   2241446    618881            90
# 6       7  31550369  25890919   3481589   1318559           139
# 7       8  33311862  29055512   3176923   1664163           102
# 8       9  32661894  30044159   3344351   1866183           152
# 9      10  33084230  30259559   3012379   2131684           216
# 10     11  32234047  30409897   3402311   2481744           218
# 11     12  31315704  27947720   3690246   2288545          2886

# %%
plt.figure(figsize=(15, 10))
plt.bar(ts5['month'],ts5['ทางถนน'],color = 'pink',label = 'ทางถนน')
plt.bar(ts5['month'],ts5['ทางราง'],color ='blue',label = 'ทางราง')
plt.bar(ts5['month'],ts5['ทางน้ำ'],color ='green',label = 'ทางน้ำ')
plt.bar(ts5['month'],ts5['ทางอากาศ'],color ='yellow',label = 'ทางอากาศ')
plt.bar(ts5['month'],ts5['จำนวนผู้ป่วย'],color ='red',label = 'จำนวนผู้ป่วย')
plt.xlabel("เดือน")
plt.ylabel("จำนวน")
plt.title('กราฟเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนนั้นๆ')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3585 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(15, 10))
plt.plot(ts5['month'],ts5['ทางถนน'],'pink',label = 'ทางถนน')
plt.plot(ts5['month'],ts5['ทางราง'],'blue',label = 'ทางราง')
plt.plot(ts5['month'],ts5['ทางน้ำ'],'green',label = 'ทางน้ำ')
plt.plot(ts5['month'],ts5['ทางอากาศ'],'yellow',label = 'ทางอากาศ')
plt.plot(ts5['month'],ts5['จำนวนผู้ป่วย'],'red',label = 'จำนวนผู้ป่วย')
plt.xlabel("เดือน")
plt.ylabel("จำนวน")
plt.title('กราฟเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนนั้นๆ')
# Out:
# Text(0.5, 1.0, 'กราฟเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนนั้นๆ')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3585 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# #สรุปข้อ 2
# #เหตุผลที่ใช้กราฟแท่งเพราะว่ากราฟแท่งมีชั้นแบ่งว่าจำนวนไหนมากน้อยกว่ากัน และกราฟเส้นเพราะว่ากราฟเส้นดูง่ายเมื่อเปรียบเทียบจำนวน
# #จากกราฟแท่งแบบแบ่งชั้นและกราฟเส้นพบว่า จำนวนผู้เดือนทางทางบกมีจำนวนคนเดินทางมากที่สุดของทุกๆเดือน รองลงมาคือทางราง ทางน้ำ ทางอากาศ  ตามลำดับ และจำนวนผู้ป่วยพบว่าน้อยมากเมื่อเทียบกับจำนวนการเดือนทางในแต่ละประเภท

# %% [markdown]
# #ข้อ3เปรียบเทียบ จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของจังหวัด top 10 ของ 6 เดือนล่าสุด

# %%
covid19 = pd.read_csv(os.path.join(path,'covid19cases.csv')) 
covid19.head()
# Out:
#    No. announce_date  ... province_of_onset district_of_onset
# 0    1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1    2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2    3     22/1/2020  ...            นครปฐม             เมือง
# 3    4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4    5     24/1/2020  ...     กรุงเทพมหานคร               NaN
#
# [5 rows x 11 columns]

# %%
from datetime import datetime
from datetime import time

# %%
covid19['announce_date'] = pd.to_datetime(covid19['announce_date'],format='%d/%m/%Y') #จัดการข้อมูลให้เป็น date time
covid19
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 0          1    2020-01-12  ...     กรุงเทพมหานคร               NaN
# 1          2    2020-01-17  ...     กรุงเทพมหานคร               NaN
# 2          3    2020-01-22  ...            นครปฐม             เมือง
# 3          4    2020-01-22  ...     กรุงเทพมหานคร               NaN
# 4          5    2020-01-24  ...     กรุงเทพมหานคร               NaN
# ...      ...           ...  ...               ...               ...
# 57505  57506    2021-04-26  ...               NaN               NaN
# 57506  57507    2021-04-26  ...               NaN               NaN
# 57507  57508    2021-04-26  ...               NaN               NaN
# 57508  57509    2021-04-26  ...               NaN               NaN
# 57509  57510    2021-04-26  ...               NaN               NaN
#
# [57510 rows x 11 columns]

# %%
# เลือกมาเฉพาะ 6 เดือนล่าสุด เนื่องจาก ข้อมูลที่ อาจาร์ให้ สิ้นสุดวันที่ 2021/04/26 จึง ต้องนับถอยหลังตามเดือน 6 เดือนก็จะได้วันที่ 2020/10/26 ตามหลักการคิดเลขของ Financal
kho3_1 =covid19[covid19['announce_date'] >= datetime(2020, 10, 26)] 
kho3_1
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 124      125    2021-03-06  ...          ปทุมธานี           ธัญบุรี
# 3737    3738    2020-10-26  ...            ชลบุรี            สัตหีบ
# 3738    3739    2020-10-26  ...     กรุงเทพมหานคร           ราชเทวี
# 3739    3740    2020-10-26  ...            ชลบุรี          บางละมุง
# 3740    3741    2020-10-26  ...            ชลบุรี          บางละมุง
# ...      ...           ...  ...               ...               ...
# 57505  57506    2021-04-26  ...               NaN               NaN
# 57506  57507    2021-04-26  ...               NaN               NaN
# 57507  57508    2021-04-26  ...               NaN               NaN
# 57508  57509    2021-04-26  ...               NaN               NaN
# 57509  57510    2021-04-26  ...               NaN               NaN
#
# [53774 rows x 11 columns]

# %%
kho3_2 = kho3_1[['No.','announce_date','province_of_onset']] #เลือกมาเฉพาะคอลัมที่ได้ใช้
kho3_2
# Out:
#          No. announce_date province_of_onset
# 124      125    2021-03-06          ปทุมธานี
# 3737    3738    2020-10-26            ชลบุรี
# 3738    3739    2020-10-26     กรุงเทพมหานคร
# 3739    3740    2020-10-26            ชลบุรี
# 3740    3741    2020-10-26            ชลบุรี
# ...      ...           ...               ...
# 57505  57506    2021-04-26               NaN
# 57506  57507    2021-04-26               NaN
# 57507  57508    2021-04-26               NaN
# 57508  57509    2021-04-26               NaN
# 57509  57510    2021-04-26               NaN
#
# [53774 rows x 3 columns]

# %%
Count3 = kho3_2.groupby('province_of_onset')['No.'].count() # หาความถี่ของ date time 
Count3
# Out:
# province_of_onset
# กระบี่             57
# กรุงเทพมหานคร    9981
# กาญจนบุรี          94
# กาฬสินธุ์          58
# กำแพงเพชร          84
#                  ...
# เลย                37
# เวียงจันทร์         1
# แพร่               49
# แม่ฮ่องสอน         36
# ไม่ระบุ             2
# Name: No., Length: 84, dtype: int64

# %%
recount3 = pd.DataFrame(Count3).reset_index() #สร้างตาราง ความถี่ของ date time 
recount3
# Out:
#    province_of_onset   No.
# 0             กระบี่    57
# 1      กรุงเทพมหานคร  9981
# 2          กาญจนบุรี    94
# 3          กาฬสินธุ์    58
# 4          กำแพงเพชร    84
# ..               ...   ...
# 79               เลย    37
# 80       เวียงจันทร์     1
# 81              แพร่    49
# 82        แม่ฮ่องสอน    36
# 83           ไม่ระบุ     2
#
# [84 rows x 2 columns]

# %%
recount3.rename(columns={'province_of_onset':'จังหวัดผู้ป่วยที่พบเชื้อ','No.':'จำนวนผู้ป่วยที่พบเชื้อ'},inplace=True) #เปลี่ยนชื่อหัวตาราง
recount3
# Out:
#    จังหวัดผู้ป่วยที่พบเชื้อ  จำนวนผู้ป่วยที่พบเชื้อ
# 0                    กระบี่                      57
# 1             กรุงเทพมหานคร                    9981
# 2                 กาญจนบุรี                      94
# 3                 กาฬสินธุ์                      58
# 4                 กำแพงเพชร                      84
# ..                      ...                     ...
# 79                      เลย                      37
# 80              เวียงจันทร์                       1
# 81                     แพร่                      49
# 82               แม่ฮ่องสอน                      36
# 83                  ไม่ระบุ                       2
#
# [84 rows x 2 columns]

# %%
kho3_3 = recount3.sort_values('จำนวนผู้ป่วยที่พบเชื้อ',ascending=False) #เรียงลำดับจำนวนผู้ป่วยที่พบเชื้อ

# %%
kho3_4 = kho3_3.iloc[0:10] #top 10 ลำดับจำนวนผู้ป่วยที่พบเชื้อ
kho3_4
# Out:
#    จังหวัดผู้ป่วยที่พบเชื้อ  จำนวนผู้ป่วยที่พบเชื้อ
# 55                สมุทรสาคร                   16005
# 1             กรุงเทพมหานคร                    9981
# 8                    ชลบุรี                    2962
# 76                เชียงใหม่                    2188
# 26                 ปทุมธานี                    1472
# 53              สมุทรปราการ                    1289
# 21                  นนทบุรี                     984
# 27          ประจวบคีรีขันธ์                     966
# 43                    ระยอง                     898
# 16                   นครปฐม                     647

# %%
kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[0]
# Out:
# 16005

# %%
#กราฟวงกลมเปรียบเทียบ จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของจังหวัด top 10 ของ 6 เดือนล่าสุด
x = np.array([kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[0],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[1],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[2],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[3],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[4],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[5],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[6],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[7],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[8],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'].iloc[9]])
mylabels = ['สมุทรสาคร', 'กรุงเทพมหานคร	', 'ชลบุรี', 'เชียงใหม่', 'ปทุมธานี','สมุทรปราการ','นนทบุรี','ประจวบคีรีขันธ์','ระยอง','นครปฐม']
fig1,ax1 = plt.subplots()
ax1.pie(x, labels=mylabels, autopct='%1.1f%%')
plt.title('จำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว')
# Out:
# Text(0.5, 1.0, 'จำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3635 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3623 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#กราฟแท่งเปรียบเทียบ จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของจังหวัด top 10 ของ 6 เดือนล่าสุด
plt.figure(figsize=(15, 10))
plt.bar(kho3_4['จังหวัดผู้ป่วยที่พบเชื้อ'],kho3_4['จำนวนผู้ป่วยที่พบเชื้อ'],data = kho3_4)
ax.bar(langs,region,color = "red")
plt.xlabel('จังหวัดของผู้ป่วยที่พบเชื้อ')
plt.ylabel('จำนวนผู้ป่วยที่พบเชื้อ')
plt.title('จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของจังหวัด top 10 ของ 6 เดือนล่าสุด')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3635 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3623 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# #สรุปข้อ 3
# #เหตุผลที่สร้างกราฟวงกลมเนื่องจากจะได้ดูความมากน้อยของผู้ป่วยตามองศาได้เพนื่องจากดูง่ายและกราฟแท่งเนื่องจากเปรียบเทียบง่ายสามารถดูได้ว่าภาคไหนมีผู้ติดเชื้อมากน้อยเพียงใด
# #จากกราฟแท่งและกราฟวงกลมพบว่า จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของจังหวัด top 10 ของ 6 เดือนล่าสุด จังหวัดที่พบผู้ติดเชื้อมากที่สุดคือจังหวัดสมุทรสาคร จำนวนผู้ติดเชื้อ  16005 คน คิดเป็น 42.8 % และรองลงมาคือ กรุงเทพมหานคร มีจำนวนผู้ติดเชื้อ 9981 คนคิดเป็น 26.7 % อันดับที่ 3 คือ จังหวัดจังหวัดชลบุรีมีจำนวนผู้ติดเชื้อ  2962 คน คิดเป็น 7.9 % อันดับที่ 4 คือ จังหวัดเชียงใหม่มีจำนวนผู้ติดเชื้อ  2188 คน คิดเป็น 5.9 % อันดับที่ 5 คือ จังหวัดปทุมธานี มีจำนวนผู้ติดเชื้อ  1472 คน คิดเป็น 3.9 % อันดับที่ 6 คือ จังหวัดสมุทรปราการ มีจำนวนผู้ติดเชื้อ  1289 คน คิดเป็น 3.4 %  อันดับที่ 7 คือ จังหวัดนนทบุรี มีจำนวนผู้ติดเชื้อ  984 คน คิดเป็น 2.6 % อันดับที่ 8 คือ จังหวัดประจวบคีรีขันธ์ มีจำนวนผู้ติดเชื้อ  966 คน คิดเป็น 2.6 %  อันดับที่ 9 คือ จังหวัดระยอง มีจำนวนผู้ติดเชื้อ  898 คน คิดเป็น 2.4 % และอันดับสุดท้ายคือจังหวัดนครปฐม มีจำนวนผู้ติดเชื้อ  647 คน คิดเป็น 1.7 %

# %% [markdown]
# #ข้อ 4 เปรียบเทียบจำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของแต่ละภูมิภาค (5 ภูมิภาค (การท่องเที่ยว)) ตามข้อมูลใน https://th.wikipedia.org/wiki/ภูมิภาคของประเทศไทย

# %%
covid19.head()
# Out:
#    No. announce_date  ... province_of_onset district_of_onset
# 0    1    2020-01-12  ...     กรุงเทพมหานคร               NaN
# 1    2    2020-01-17  ...     กรุงเทพมหานคร               NaN
# 2    3    2020-01-22  ...            นครปฐม             เมือง
# 3    4    2020-01-22  ...     กรุงเทพมหานคร               NaN
# 4    5    2020-01-24  ...     กรุงเทพมหานคร               NaN
#
# [5 rows x 11 columns]

# %%
#แบ่งภูมิภาค 5 ภาค

# %%
#nort east
ne1 = covid19[covid19['province_of_onset']== 'อำนาจเจริญ']
ne2 = covid19[covid19['province_of_onset']== 'บึงกาฬ']
ne3 = covid19[covid19['province_of_onset']== 'บุรีรัมย์']
ne4 = covid19[covid19['province_of_onset']== 'ชัยภูมิ']
ne5 = covid19[covid19['province_of_onset']== 'กาฬสินธุ์']
ne6 = covid19[covid19['province_of_onset']== 'ขอนแก่น']
ne7 = covid19[covid19['province_of_onset']== 'เลย']
ne8 = covid19[covid19['province_of_onset']== 'มหาสารคาม']
ne9 = covid19[covid19['province_of_onset']== 'มุกดาหาร']
ne10 = covid19[covid19['province_of_onset']== 'นครพนม']
ne11= covid19[covid19['province_of_onset']== 'นครราชสีมา']
ne12= covid19[covid19['province_of_onset']== 'หนองบัวลำภู']
ne13= covid19[covid19['province_of_onset']== 'หนองคาย']
ne14= covid19[covid19['province_of_onset']== 'ร้อยเอ็ด']
ne15= covid19[covid19['province_of_onset']== 'สกลนคร']
ne16= covid19[covid19['province_of_onset']== 'ศรีสะเกษ']
ne17= covid19[covid19['province_of_onset']== 'สุรินทร์']
ne18= covid19[covid19['province_of_onset']== 'อุบลราชธานี']
ne19= covid19[covid19['province_of_onset']== 'อุดรธานี']
ne20= covid19[covid19['province_of_onset']== 'ยโสธร']
ne1
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 972      973    2020-03-26  ...        อำนาจเจริญ             เมือง
# 1863    1864    2020-04-02  ...        อำนาจเจริญ       ปทุมราชวงศา
# 6492    6493    2020-12-30  ...        อำนาจเจริญ          หัวตะพาน
# 7389    7390    2021-01-03  ...        อำนาจเจริญ          หัวตะพาน
# 31037  31038    2021-04-10  ...        อำนาจเจริญ             เมือง
# 31038  31039    2021-04-10  ...        อำนาจเจริญ             เมือง
# 32916  32917    2021-04-12  ...        อำนาจเจริญ           ชานุมาน
# 32917  32918    2021-04-12  ...        อำนาจเจริญ          หัวตะพาน
# 36500  36501    2021-04-15  ...        อำนาจเจริญ           ชานุมาน
# 36501  36502    2021-04-15  ...        อำนาจเจริญ   เมืองอำนาจเจริญ
# 36502  36503    2021-04-15  ...        อำนาจเจริญ           ชานุมาน
# 37766  37767    2021-04-16  ...        อำนาจเจริญ   เมืองอำนาจเจริญ
# 37767  37768    2021-04-16  ...        อำนาจเจริญ          หัวตะพาน
# ...

# %%
NorthEast = pd.concat([ne1,ne2,ne3,ne4,ne5,ne6,ne7,ne8,ne9,ne10,ne11,ne12,ne13,ne14,ne15,ne16,ne17,ne18,ne19,ne20])
NorthEast #รวมภาคตะวันออกเฉียงเหนือ
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 972      973    2020-03-26  ...        อำนาจเจริญ             เมือง
# 1863    1864    2020-04-02  ...        อำนาจเจริญ       ปทุมราชวงศา
# 6492    6493    2020-12-30  ...        อำนาจเจริญ          หัวตะพาน
# 7389    7390    2021-01-03  ...        อำนาจเจริญ          หัวตะพาน
# 31037  31038    2021-04-10  ...        อำนาจเจริญ             เมือง
# ...      ...           ...  ...               ...               ...
# 55567  55568    2021-04-26  ...             ยโสธร            ค้อวัง
# 55568  55569    2021-04-26  ...             ยโสธร            ค้อวัง
# 55575  55576    2021-04-26  ...             ยโสธร          เลิงนกทา
# 55576  55577    2021-04-26  ...             ยโสธร             เมือง
# 55577  55578    2021-04-26  ...             ยโสธร             เมือง
#
# [2345 rows x 11 columns]

# %%
#nort
n1 = covid19[covid19['province_of_onset']== 'เชียงใหม่']
n2 = covid19[covid19['province_of_onset']== 'เชียงราย']
n3 = covid19[covid19['province_of_onset']== 'ลำปาง']
n4 = covid19[covid19['province_of_onset']== 'ลำพูน']
n5 = covid19[covid19['province_of_onset']== 'แม่ฮ่องสอน']
n6 = covid19[covid19['province_of_onset']== 'น่าน']
n7 = covid19[covid19['province_of_onset']== 'พะเยา']
n8 = covid19[covid19['province_of_onset']== 'แพร่']
n9 = covid19[covid19['province_of_onset']== 'อุตรดิตถ์']
n10 = covid19[covid19['province_of_onset']== 'ตาก']
n11 = covid19[covid19['province_of_onset']== 'สุโขทัย']
n12 = covid19[covid19['province_of_onset']== 'พิษณุโลก']
n13 = covid19[covid19['province_of_onset']== 'พิจิตร']
n14 = covid19[covid19['province_of_onset']== 'กำแพงเพชร']
n15 = covid19[covid19['province_of_onset']== 'เพชรบูรณ์']
n16 = covid19[covid19['province_of_onset']== 'นครสวรรค์']
n17 = covid19[covid19['province_of_onset']== 'อุทัยธานี']
n1
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 16        17    2020-01-31  ...         เชียงใหม่             หางดง
# 91        92    2020-03-15  ...         เชียงใหม่            แม่ริม
# 185      186    2020-03-18  ...         เชียงใหม่          นครพิงค์
# 192      193    2020-03-18  ...         เชียงใหม่               NaN
# 252      253    2020-03-19  ...         เชียงใหม่               NaN
# ...      ...           ...  ...               ...               ...
# 56266  56267    2021-04-26  ...         เชียงใหม่    เมืองเชียงใหม่
# 56267  56268    2021-04-26  ...         เชียงใหม่           สันทราย
# 56268  56269    2021-04-26  ...         เชียงใหม่           สันทราย
# 56269  56270    2021-04-26  ...         เชียงใหม่             สารภี
# 56270  56271    2021-04-26  ...         เชียงใหม่          สันกำแพง
#
# [2229 rows x 11 columns]

# %%
North= pd.concat([n1,n2,n3,n4,n5,n6,n7,n8,n9,n10,n11,n12,n13,n14,n15,n16,n17])
North #รวมภาคเหนือ
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 16        17    2020-01-31  ...         เชียงใหม่             หางดง
# 91        92    2020-03-15  ...         เชียงใหม่            แม่ริม
# 185      186    2020-03-18  ...         เชียงใหม่          นครพิงค์
# 192      193    2020-03-18  ...         เชียงใหม่               NaN
# 252      253    2020-03-19  ...         เชียงใหม่               NaN
# ...      ...           ...  ...               ...               ...
# 54030  54031    2021-04-25  ...         อุทัยธานี            ลานสัก
# 55389  55390    2021-04-25  ...         อุทัยธานี    เมืองอุทัยธานี
# 55399  55400    2021-04-25  ...         อุทัยธานี    เมืองอุทัยธานี
# 56185  56186    2021-04-26  ...         อุทัยธานี           หนองฉาง
# 56186  56187    2021-04-26  ...         อุทัยธานี           หนองฉาง
#
# [4373 rows x 11 columns]

# %%
#mid
m1 = covid19[covid19['province_of_onset']== 'อ่างทอง']
m2 = covid19[covid19['province_of_onset']== 'ชัยนาท']
m3 = covid19[covid19['province_of_onset']== 'พระนครศรีอยุธยา ']
m4 = covid19[covid19['province_of_onset']== 'กรุงเทพมหานคร']
m5 = covid19[covid19['province_of_onset']== 'ลพบุรี']
m6 = covid19[covid19['province_of_onset']== 'นครปฐม']
m7 = covid19[covid19['province_of_onset']== 'นนทบุรี']
m8 = covid19[covid19['province_of_onset']== 'ปทุมธานี']
m9 = covid19[covid19['province_of_onset']== 'สมุทรปราการ']
m10 = covid19[covid19['province_of_onset']== 'สมุทรสาคร']
m11 = covid19[covid19['province_of_onset']== 'สมุครสงคราม']
m12 = covid19[covid19['province_of_onset']== 'สระบุรี']
m13 = covid19[covid19['province_of_onset']== 'สิงห์บุรี']
m14 = covid19[covid19['province_of_onset']== 'สุพรรณบุรี']
m15 = covid19[covid19['province_of_onset']== 'นครนายก']
m16 = covid19[covid19['province_of_onset']== 'กาญจนบุรี']
m17 = covid19[covid19['province_of_onset']== 'ราชบุรี']
m18 = covid19[covid19['province_of_onset']== 'เพชรบุรี']
m19 = covid19[covid19['province_of_onset']== 'ประจวบคีรีขันธ์']
m1
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 5808    5809    2020-12-24  ...           อ่างทอง             เมือง
# 6688    6689    2020-12-30  ...           อ่างทอง          โพธิ์ทอง
# 6892    6893    2021-01-01  ...           อ่างทอง             เมือง
# 7172    7173    2021-01-02  ...           อ่างทอง             เมือง
# 7390    7391    2021-01-03  ...           อ่างทอง          โพธิ์ทอง
# ...      ...           ...  ...               ...               ...
# 56136  56137    2021-04-26  ...           อ่างทอง       วิเศษชัยชาญ
# 56137  56138    2021-04-26  ...           อ่างทอง            ป่าโมก
# 56138  56139    2021-04-26  ...           อ่างทอง      เมืองอ่างทอง
# 56139  56140    2021-04-26  ...           อ่างทอง      เมืองอ่างทอง
# 56140  56141    2021-04-26  ...           อ่างทอง      เมืองอ่างทอง
#
# [167 rows x 11 columns]

# %%
Mid = pd.concat([m1,m2,m3,m4,m5,m6,m7,m8,n9,m10,m11,m12,m13,m14,m15,m16,m17,m18,m19])
Mid #รวมภาคกลาง
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 5808    5809    2020-12-24  ...           อ่างทอง             เมือง
# 6688    6689    2020-12-30  ...           อ่างทอง          โพธิ์ทอง
# 6892    6893    2021-01-01  ...           อ่างทอง             เมือง
# 7172    7173    2021-01-02  ...           อ่างทอง             เมือง
# 7390    7391    2021-01-03  ...           อ่างทอง          โพธิ์ทอง
# ...      ...           ...  ...               ...               ...
# 55999  56000    2021-04-26  ...   ประจวบคีรีขันธ์          ปราณบุรี
# 56000  56001    2021-04-26  ...   ประจวบคีรีขันธ์            หัวหิน
# 56001  56002    2021-04-26  ...   ประจวบคีรีขันธ์            หัวหิน
# 56002  56003    2021-04-26  ...   ประจวบคีรีขันธ์            หัวหิน
# 56003  56004    2021-04-26  ...   ประจวบคีรีขันธ์            หัวหิน
#
# [33724 rows x 11 columns]

# %%
#east
e1 = covid19[covid19['province_of_onset']== 'ฉะเชิงเทรา']
e2 = covid19[covid19['province_of_onset']== 'จันทบุรี']
e3 = covid19[covid19['province_of_onset']== 'ชลบุรี']
e4 = covid19[covid19['province_of_onset']== 'ปราจีนบุรี']
e5 = covid19[covid19['province_of_onset']== 'ระยอง']
e6 = covid19[covid19['province_of_onset']== 'สระแก้ว']
e7 = covid19[covid19['province_of_onset']== 'ตราด']
e1
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 119      120    2020-03-16  ...        ฉะเชิงเทรา               NaN
# 305      306    2020-03-20  ...        ฉะเชิงเทรา               NaN
# 408      409    2020-03-21  ...        ฉะเชิงเทรา               NaN
# 531      532    2020-03-22  ...        ฉะเชิงเทรา               NaN
# 614      615    2020-03-23  ...        ฉะเชิงเทรา               NaN
# ...      ...           ...  ...               ...               ...
# 56492  56493    2021-04-26  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 56493  56494    2021-04-26  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 56494  56495    2021-04-26  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 56495  56496    2021-04-26  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 56496  56497    2021-04-26  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
#
# [229 rows x 11 columns]

# %%
East= pd.concat([e1,e2,e3,e4,e5,e6,e7])
East #รวมภาคตะวันออก
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 119      120    2020-03-16  ...        ฉะเชิงเทรา               NaN
# 305      306    2020-03-20  ...        ฉะเชิงเทรา               NaN
# 408      409    2020-03-21  ...        ฉะเชิงเทรา               NaN
# 531      532    2020-03-22  ...        ฉะเชิงเทรา               NaN
# 614      615    2020-03-23  ...        ฉะเชิงเทรา               NaN
# ...      ...           ...  ...               ...               ...
# 56324  56325    2021-04-26  ...              ตราด          เกาะช้าง
# 56325  56326    2021-04-26  ...              ตราด         เมืองตราด
# 56326  56327    2021-04-26  ...              ตราด         เมืองตราด
# 56327  56328    2021-04-26  ...              ตราด           เขาสมิง
# 56328  56329    2021-04-26  ...              ตราด         เมืองตราด
#
# [5232 rows x 11 columns]

# %%
#sout
s1 = covid19[covid19['province_of_onset']== 'ชุมพร']
s2 = covid19[covid19['province_of_onset']== 'นครศรีธรรมราช']
s3 = covid19[covid19['province_of_onset']== 'ระนอง']
s4 = covid19[covid19['province_of_onset']== 'นราธิวาส']
s5 = covid19[covid19['province_of_onset']== 'ปัตตานี']
s6 = covid19[covid19['province_of_onset']== 'พัทลุง']
s7 = covid19[covid19['province_of_onset']== 'สงขลา']
s8 = covid19[covid19['province_of_onset']== 'สุราษฎร์ธานี']
s9 = covid19[covid19['province_of_onset']== 'ยะลา']
s10 = covid19[covid19['province_of_onset']== 'กระบี่']
s11 = covid19[covid19['province_of_onset']== 'พังงา']
s12 = covid19[covid19['province_of_onset']== 'ภูเก็ต']
s13 = covid19[covid19['province_of_onset']== 'สตูล']
s14 = covid19[covid19['province_of_onset']== 'ตรัง']
s1
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 1529    1530    2020-03-31  ...             ชุมพร           หลังสวน
# 2255    2256    2020-04-07  ...             ชุมพร             เมือง
# 2461    2462    2020-04-10  ...             ชุมพร             เมือง
# 2576    2577    2020-04-13  ...             ชุมพร             เมือง
# 2620    2621    2020-04-15  ...             ชุมพร             เมือง
# ...      ...           ...  ...               ...               ...
# 55581  55582    2021-04-26  ...             ชุมพร            ท่าแซะ
# 55582  55583    2021-04-26  ...             ชุมพร             เมือง
# 55583  55584    2021-04-26  ...             ชุมพร             เมือง
# 55584  55585    2021-04-26  ...             ชุมพร             เมือง
# 55585  55586    2021-04-26  ...             ชุมพร             เมือง
#
# [79 rows x 11 columns]

# %%
Sout = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14])
Sout #รวมภาครวมภาคใต้
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 1529    1530    2020-03-31  ...             ชุมพร           หลังสวน
# 2255    2256    2020-04-07  ...             ชุมพร             เมือง
# 2461    2462    2020-04-10  ...             ชุมพร             เมือง
# 2576    2577    2020-04-13  ...             ชุมพร             เมือง
# 2620    2621    2020-04-15  ...             ชุมพร             เมือง
# ...      ...           ...  ...               ...               ...
# 56066  56067    2021-04-26  ...              ตรัง           ห้วยยอด
# 56067  56068    2021-04-26  ...              ตรัง             เมือง
# 56068  56069    2021-04-26  ...              ตรัง             เมือง
# 56069  56070    2021-04-26  ...              ตรัง             เมือง
# 56070  56071    2021-04-26  ...              ตรัง             เมือง
#
# [3274 rows x 11 columns]

# %%
kho4 = pd.concat([NorthEast,North,Mid,Sout,East])

# %%
#สร้างกราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของแต่ละภูมิภาค (5 ภูมิภาค (การท่องเที่ยว))
y = np.array([NorthEast.shape[0],North.shape[0],Mid.shape[0],East.shape[0],Sout.shape[0]])
mylabels = ['ภาคตะวันออกเฉียงเหนือ', 'ภาคเหนือ', 'ภาคกลาง', 'ภาคตะวันออก', 'ภาคใต้']
fig1,ax1 = plt.subplots()
ax1.pie(y, labels=mylabels, autopct='%1.1f%%')
plt.title('จำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว')
# Out:
# Text(0.5, 1.0, 'จำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3635 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3623 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#สร้างกราฟแท่งเปรียบเทียบจำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของแต่ละภูมิภาค 5 ภูมิภาค (การท่องเที่ยว)
fig = plt.figure(figsize=(5, 2))
ax = fig.add_axes([2,2,2,2])
ax.bar(langs,region,color = "green")
langs = ['ภาคตะวันออกเฉียงเหนือ', 'ภาคเหนือ', 'ภาคกลาง', 'ภาคตะวันออก', 'ภาคใต้']
region = [NorthEast.shape[0],North.shape[0],Mid.shape[0],East.shape[0],Sout.shape[0]]
plt.ylabel('จำนวนผู้ป่วยที่พบ หน่วย:คน')
plt.xlabel('ภูมิภาคตามการท่องเที่ยว')
plt.title('จำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว')
# Out:
# Text(0.5, 1.0, 'จำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3635 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3623 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# #สรุปข้อ 4
# #เหตุผลที่สร้างกราฟวงกลมเนื่องจากจะได้ดูความมากน้อยของผู้ป่วยตามองศาได้เพนื่องจากดูง่ายและกราฟแท่งเนื่องจากเปรียบเทียบง่ายสามารถดูได้ว่าภาคไหนมีผู้ติดเชื้อมากน้อยเพียงใด
# #สรุปผลจากกราฟวงกลมและกราฟแท่งจำนวนผู้ป่วยที่ตรวจพบเชื้อ COVID-19 แต่ละภูมิภาคจำแนกตามภาคการท่องเที่ยว พบว่า ภาคกลางมีผู้ติดเชื้อมากที่สุด ประมาณ 35000 คน คิดเป็น 68.9 เปอร์เซ็น และรองลงมาคือ ภาคตะวันออก 5000-6000 คน คิดเป็น 10.7 เปอร์เซ็น ภาคเหนือ 5000 คน 8.9 เปอร์เซ็น ภาคใต้ เกือบ 5000 คน 6.7 เปอร์เซ็น และภาคที่พบผู้ติดเชื้อ COVID-19 คือภาคตะวันออกเฉียงเหนือ ประมาณ 3000 คน คิดเป็น 4.8 เปอร์เซ็น
